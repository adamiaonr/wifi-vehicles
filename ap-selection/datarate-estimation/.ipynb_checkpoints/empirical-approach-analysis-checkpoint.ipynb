# %% [markdown]
# # Data rate prediction notebook
# The question we're trying to answer: how well can an AP predict the data rate a client will experience when it connects to it, using historical data?

# %% [markdown]
# ## Data set
#
# Contains a time-indexed summary of the WiFi experiments performed at FEUP during January 2019.
#
# In these experiments there were 4 stationary APs sending data through UDP to 4 mobile clients.
# All APs used 802.11n, but each used its own independent channel.
#
# Clients performed "laps" back and forth around the APs.
#
# AP info:
#
# * ap1, located at (41.178518,-8.595366), running on channel 6 (20 MHz centered at 2437 MHz)
# * ap2, located at (41.178518,-8.595366), running on channel 38 (40 MHz centered at 5190 MHz)
# * ap3, located at (41.178563,-8.596012), running on channel 11 (20 MHz centered at 2462 MHz)
# * ap4, located at (41.178563,-8.596012), running on channel 46 (40 MHz centered at 5230 MHz)
#
#
# ### Column explanation
#
# * senderId: id of the node sending data (one of {ap1, ap2, ap3, ap4}).
#
# * receiverId: id of the client node receiving data (one of {m1, w1, w2, w3}).
#
# * systime: system time (1 Hz resolution) that this row refers to. All node clocks were synchronized through NTP.
#
# * receiverDist: straight-line distance between sender and receiver, in meters, for the 1-second period systime period the row refers to. If we don't have data for a particular systime, linear interpolation between the two closest data points is used.
#
# * receiverX: x coordinate of the receiver's position when space is discretized as a Cartesian plane and the sender is set to be the origin of the coordinate system. The x axis corresponds to east-west (positive values are east, negative values are west). Unit is meters. If we don't have data for a particular systime, linear interpolation between the two closest data points is used.
#
# * receiverY: y coordinate of the receiver's position when space is discretized as a Cartesian plane and the sender is set to be the origin of the coordinate system. The y axis corresponds to north-south (positive values are north, negative values are south). Unit is meters. If we don't have data for a particular systime, linear interpolation between the two closest data points is used.
#
# * receiverAlt: receiver's altitude, in meters.
#
# * receiverSpeed: receiver's speed, in m/s.
#
# * channelFreq: center frequency of the WiFi channel used, in MHz.
#
# * channelBw: bandwidth of the WiFi channel used, in MHz.
#
# * channelUtil: percentage of time the wireless medium was sensed to be busy during the 1-second period systime period the row refers to. If we don't have data for a particular systime, linear interpolation between the two closest data points is used.
#
# * isInLap: 1 if this row's systime has been marked as being part of a time period where clients were doing laps around the APs, 0 otherwise.
#
# * isIperfOn: 1 if row's systime corresponds to a period where iperf is known to have been running on the receiver side.
#
# * rssiMean: the mean of the RSSI (Received Signal Strength Indicator) values of frames received by the client from the sender during the 1-second period systime period the row refers to. If no frames with RSSI information were received, this field is set to -100. Unit is dBm.
#
# * dataRateMean: the mean of the RSSI (Received Signal Strength Indicator) values of frames received by the client from the sender during the 1-second period systime period the row refers to. If no frames with RSSI information were received, this field is set to 0. Unit is Mbit/s.
#
# * nBytesReceived: total number of bytes received by the client from the sender during the 1-second period systime period the row refers to.

# %% [markdown]
# ### Data set loading
# To note:
# * We keep only data for colocated APs, either the (ap1, ap2) pair, or the (ap3, ap4) pair. This emulates a scenario where one AP supports multiple technologies.
# * The throw away rows marked as having iperf turned off.

# %%
import pandas

IN_FNAME = "../data/feup-exp-201901/summary/final-exp-log.csv"

# load dataset
# line format: senderId,receiverId,systime,receiverX,receiverY,receiverAlt,
#              receiverSpeed,channelFreq,channelBw,chanUtil,isInLap,isIperfOn,
#              isDataResheived,rssiMean,dataRateMean,nBytesReceived -0976543

dataset = pandas.read_csv(IN_FNAME)
dataset = dataset.loc[dataset['isIperfOn'] == 1] # filter out periods when iperf was off
dataset = dataset.loc[dataset['senderId'].isin(('ap1','ap2'))] # filter out non-colocated APs
dataset = dataset.reset_index(drop=True)

# %% [markdown]
# ## Feature correlation analysis
# ### Code

# %%
# let us print out a correlation matrix (weirdly, can't farm this out to a method
# because then it won't show in the notebook)

# prepare a data set for correlation analysis
corDs = dataset.copy()

# drop unneeded columns
corDs.drop(['systime', 'isInLap', 'senderId', 'receiverId', 'isIperfOn'], axis=1, inplace=True)

#corDs # uncomment if you want to print it out

# %%
# show correlation matrix for pearson (measures linear relationship between normally-distributed variables)
corMat = corDs.corr(method='pearson') 
corMat.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row0_col1 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row0_col2 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row0_col3 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row0_col4 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row0_col5 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row0_col6 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row0_col7 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row0_col8 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row0_col9 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row0_col10 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row1_col0 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row1_col2 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row1_col3 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row1_col4 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row1_col5 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row1_col6 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row1_col7 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row1_col8 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row1_col9 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row1_col10 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row2_col0 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row2_col1 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row2_col3 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row2_col4 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row2_col5 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row2_col6 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row2_col7 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row2_col8 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row2_col9 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row2_col10 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row3_col0 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row3_col1 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row3_col2 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row3_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row3_col5 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row3_col6 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row3_col7 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row3_col8 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row3_col9 {
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row3_col10 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row4_col0 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row4_col1 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row4_col2 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row4_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row4_col5 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row4_col6 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row4_col7 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row4_col8 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row4_col9 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row4_col10 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row5_col0 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row5_col1 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row5_col2 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row5_col3 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_c1fb20ee_a7b9_11e9_9da1_88e9fe65fe46row5_col4 {
#             background-color:  #d2dbe8;
#             color:  #000000

# %%
corMat = corDs.corr(method='kendall') # non-parametric, rank based (sees how increasing rank of one variable changes rank of another)
                                      # spearman is alternative, gives higher values but is more error prone
corMat.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row0_col1 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row0_col2 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row0_col3 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row0_col4 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row0_col5 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row0_col6 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row0_col7 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row0_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row0_col9 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row0_col10 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row1_col0 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row1_col2 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row1_col3 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row1_col4 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row1_col5 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row1_col6 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row1_col7 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row1_col8 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row1_col9 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row1_col10 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row2_col0 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row2_col1 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row2_col4 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row2_col5 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row2_col6 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row2_col7 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row2_col8 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row2_col9 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row2_col10 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row3_col0 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row3_col1 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row3_col4 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row3_col5 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row3_col6 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row3_col7 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row3_col8 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row3_col9 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row3_col10 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row4_col0 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row4_col1 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row4_col2 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row4_col3 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row4_col5 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row4_col6 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row4_col7 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row4_col8 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row4_col9 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row4_col10 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row5_col0 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row5_col1 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row5_col2 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row5_col3 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_c222e5d4_a7b9_11e9_9da1_88e9fe65fe46row5_col4 {
#             background-color:  #b9d0f9;
#             color:  #000000

# %%
corMat = corDs.corr(method='spearman') # non-parametric, rank based (sees how increasing rank of one variable changes rank of another)
                                      # compared to kendall, gives higher values but is more error prone
corMat.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row0_col1 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row0_col2 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row0_col3 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row0_col4 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row0_col5 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row0_col6 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row0_col7 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row0_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row0_col9 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row0_col10 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row1_col0 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row1_col2 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row1_col3 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row1_col4 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row1_col5 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row1_col6 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row1_col7 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row1_col8 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row1_col9 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row1_col10 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row2_col0 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row2_col1 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row2_col3 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row2_col4 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row2_col5 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row2_col6 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row2_col7 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row2_col8 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row2_col9 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row2_col10 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row3_col0 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row3_col1 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row3_col2 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row3_col4 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row3_col5 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row3_col6 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row3_col7 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row3_col8 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row3_col9 {
#             background-color:  #f2cab5;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row3_col10 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row4_col0 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row4_col1 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row4_col2 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row4_col3 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row4_col5 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row4_col6 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row4_col7 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row4_col8 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row4_col9 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row4_col10 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row5_col0 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row5_col1 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row5_col2 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row5_col3 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_c24552c2_a7b9_11e9_9da1_88e9fe65fe46row5_col4 {
#             background-color:  #cfdaea;
#             color:  #000000

# %%
del corDs, corMat # get rid of stuff we don't need anymore

# %% [markdown]
# ### Results discussion
# * RSSI is reasonably correlated with throughput.
# * Distance is reasonably negatively-correlated with throughput, as expected.
# * RSSI and distance correlate pretty well with one another.
# * Channel utilization is not useful in this data set because there is only one client per channel.
# * Data rate is pretty much a dead ringer for throughput. I'm thinking we should actually focus on predicting data rate rather than throughput. Data rate should be easier to predict as it's independent from the amount of data the client has to send.

# %% [markdown]
# ## Data rate prediction as a classification problem
# I.e. predict data rate as discrete variable.
# We discretize data rate as a 4-class variable, with each class representing a different quartile.
#
# Notes regarding classification report:
# * **precision**: TP / (TP + FP), or what percentage of predicted positives are true positives.
# * **recall**: TP / (TP+FN), or what percentage of actual positives were predicted to be positive.
# * **f1-score**: can be interpreted as a weighted harmonic mean of precision and recall, (best score is 1, worst is 0).
# * **support**: number of ground truth entries in the corresponding.
#
#
#
# ### Code

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sn
import matplotlib.pyplot as plt
import numpy

def printSeparator():
  print('----------------------------------------------------------------\n')

def evalClfPerf(clfName, yTest, yPred):
  print("Accuracy of", clfName, ":", accuracy_score(yTest, yPred))
  print(classification_report(yTest, yPred))

  # display a confusion matrix
  print("Confusion matrix:")
  cmat = confusion_matrix(yTest, yPred)
  plt.figure(figsize=(6.5, 6.5)) # new figure
  sn.set(font_scale=1.4) #for label size
  sn.heatmap(cmat, annot=True, annot_kws={"size": 13}, fmt='g') # font size
  plt.show()

def plotRfFeatImp(x, featNameList, clfRf):
  """
    Plot feature importance over feature data frame x for a random forest classifier clfRf.
  """
  std = numpy.std([tree.feature_importances_ for tree in clfRf.estimators_], axis=0)
  indices = numpy.argsort(clfRf.feature_importances_)[::-1]

  print("Feature importance:")
  plt.figure()
  ax = plt.bar(range(x.shape[1]), clfRf.feature_importances_[indices], yerr=std[indices], \
          align="center", color="r")
  plt.xticks(range(x.shape[1]), [featNameList[i] for i in indices], rotation = 90)
  plt.xlim([-1, x.shape[1]])
  plt.ylim([0, 0.5])
  plt.show()

def runClassifier(clf, clfName, xTrain, yTrain, xTest, yTest):
  """
    Run single classifier, passed in as argument clf.
  """

  clf.fit(xTrain, yTrain)
  yPred = clf.predict(xTest) # predict on the unseen data
  evalClfPerf(clfName, yTest, yPred)
  printSeparator()

def runClassifiersInner(df, targetName, scaler=None, nquantiles=4):
  """
    Run multiple classifiers for the data frame passed in as argument df.
  """

  # discretize target

  # start by printing some information about the bins
  uniBins = pandas.qcut(df[targetName], q=nquantiles).unique()
  uniBins = uniBins.ravel()
  uniBins.sort()
  print("Discretizing", targetName, "into", nquantiles, "quantiles, yielding bins:\n", uniBins)

  df[targetName] = pandas.qcut(df[targetName], q=nquantiles, labels=False) # actually discretize stuff

  #  split dataset into training and test
  x = df.drop(targetName, axis=1) # x contains all the features
  y = df[targetName] # y contains only the label
  featNameList = list(x.columns)

  # scaling, see: https://towardsdatascience.com/scale-standardize-or-normalize-with-scikit-learn-6ccc7d176a02
  if scaler:
    x = scaler.fit_transform(x)

  # xTrain contains features for training, xTest contains features for testing
  # test_size = 0.3 means 30% data for testing
  # random_state = 1, is the seed value used by the random number generator
  xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.3, random_state=1)
  printSeparator()
    
  # train and test models

  # logistic regression
  clfLogr = LogisticRegression(solver='lbfgs', multi_class='auto', max_iter=10000, random_state=1)
  runClassifier(clfLogr, "logistic regression", xTrain, yTrain, xTest, yTest)
    
  # svm
  clfSvm = svm.SVC(gamma='scale', random_state=1)
  runClassifier(clfSvm, "support vector machine", xTrain, yTrain, xTest, yTest)
    
  # knn
  clfKnn = KNeighborsClassifier()
  runClassifier(clfKnn, "k-Nearest Neighbors", xTrain, yTrain, xTest, yTest)

  # decision tree    
  clfDt = DecisionTreeClassifier(random_state=1)
  runClassifier(clfDt, "decision tree", xTrain, yTrain, xTest, yTest)

  # random forest
  clfRf = RandomForestClassifier(n_estimators=100, random_state=1)
  runClassifier(clfRf, "random forest", xTrain, yTrain, xTest, yTest)
  plotRfFeatImp(x, featNameList, clfRf)
    
  # neural network (Multi Layer Perceptron w/ backpropagation)
  clfMlp = MLPClassifier(solver='lbfgs', random_state=1, max_iter=1000)
  runClassifier(clfMlp, "neural network - Multi-Layer Perceptron (MLP)", xTrain, yTrain, xTest, yTest)

# %% [markdown]
# ### Classification on original features
# #### Code

# %%
def runClassifiersOuterOg(df, featuresToDrop): 

  clDf = df.copy() # work on copy to preserve original

  # we don't care for some columns no more
  clDf.drop(featuresToDrop, axis=1, inplace=True)
  
  #  split dataset into training and test
  x = clDf.drop("dataRateMean", axis=1) # x contains all the features
  y = clDf["dataRateMean"] # y contains only the label

  from sklearn.preprocessing import MinMaxScaler
  mms = MinMaxScaler() # subtract minimum and divide by range
  runClassifiersInner(df=clDf, targetName="dataRateMean", scaler=mms, nquantiles=4)

# %% [markdown]
# #### Classification with client location data
# Requires some communication from client to AP.

# %%
runClassifiersOuterOg(df=dataset, 
                      featuresToDrop=['systime', 'isInLap', 'isIperfOn', \
                                      'senderId', 'receiverId', 'receiverDist', \
                                      'channelUtil', 'nBytesReceived'])
# Out:
# Discretizing dataRateMean into 4 quantiles, yielding bins:
#  [Interval(-0.001, 8.625, closed='right')
#  Interval(8.625, 62.89, closed='right')
#  Interval(62.89, 104.029, closed='right')
#  Interval(104.029, 292.69, closed='right')]
# ----------------------------------------------------------------
#
# Accuracy of logistic regression : 0.8036036036036036
#               precision    recall  f1-score   support
#
#            0       0.78      0.87      0.82       402
#            1       0.71      0.68      0.70       408
#            2       0.93      0.74      0.82       435
#            3       0.81      0.92      0.87       420
#
#     accuracy                           0.80      1665
#    macro avg       0.81      0.80      0.80      1665
# weighted avg       0.81      0.80      0.80      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Accuracy of support vector machine : 0.8384384384384385
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.83       402
#            1       0.86      0.69      0.77       408
#            2       0.89      0.84      0.87       435
#            3       0.83      0.94      0.88       420
#
#     accuracy                           0.84      1665
#    macro avg       0.84      0.84      0.84      1665
# weighted avg       0.84      0.84      0.84      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Accuracy of k-Nearest Neighbors : 0.8744744744744745
#               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87       402
#            1       0.84      0.81      0.82       408
#            2       0.87      0.86      0.87       435
#            3       0.92      0.94      0.93       420
#
#     accuracy                           0.87      1665
#    macro avg       0.87      0.87      0.87      1665
# weighted avg       0.87      0.87      0.87      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Accuracy of decision tree : 0.8402402402402402
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.85       402
#            1       0.78      0.76      0.77       408
#            2       0.82      0.84      0.83       435
#            3       0.90      0.92      0.91       420
#
#     accuracy                           0.84      1665
#    macro avg       0.84      0.84      0.84      1665
# weighted avg       0.84      0.84      0.84      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Accuracy of random forest : 0.8876876876876877
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.90       402
#            1       0.86      0.82      0.84       408
#            2       0.89      0.87      0.88       435
#            3       0.92      0.95      0.93       420
#
#     accuracy                           0.89      1665
#    macro avg       0.89      0.89      0.89      1665
# weighted avg       0.89      0.89      0.89      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
# Accuracy of neural network - Multi-Layer Perceptron (MLP) : 0.8744744744744745
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87       402
#            1       0.84      0.83      0.84       408
#            2       0.88      0.85      0.87       435
#            3       0.89      0.95      0.92       420
#
#     accuracy                           0.87      1665
#    macro avg       0.87      0.87      0.87      1665
# weighted avg       0.87      0.87      0.87      1665
#
# Confusion matrix:
# ----------------------------------------------------------------

# %% [markdown]
# #### Classification without client location data
# Doesn't require communication from client to AP.

# %%
runClassifiersOuterOg(df=dataset, 
                      featuresToDrop=['systime', 'isInLap', 'isIperfOn', 'senderId', \
                                      'receiverId', 'receiverX', 'receiverY', \
                                      'receiverDist', 'receiverSpeed', 'receiverAlt', \
                                      'channelUtil', 'nBytesReceived'])
# Out:
# Discretizing dataRateMean into 4 quantiles, yielding bins:
#  [Interval(-0.001, 8.625, closed='right')
#  Interval(8.625, 62.89, closed='right')
#  Interval(62.89, 104.029, closed='right')
#  Interval(104.029, 292.69, closed='right')]
# ----------------------------------------------------------------
#
# Accuracy of logistic regression : 0.775975975975976
#               precision    recall  f1-score   support
#
#            0       0.73      0.81      0.77       402
#            1       0.92      0.55      0.69       408
#            2       0.86      0.74      0.79       435
#            3       0.70      1.00      0.82       420
#
#     accuracy                           0.78      1665
#    macro avg       0.80      0.78      0.77      1665
# weighted avg       0.80      0.78      0.77      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Accuracy of support vector machine : 0.787987987987988
#               precision    recall  f1-score   support
#
#            0       0.69      0.87      0.77       402
#            1       0.89      0.58      0.70       408
#            2       0.88      0.72      0.79       435
#            3       0.77      0.99      0.86       420
#
#     accuracy                           0.79      1665
#    macro avg       0.81      0.79      0.78      1665
# weighted avg       0.81      0.79      0.78      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Accuracy of k-Nearest Neighbors : 0.766966966966967
#               precision    recall  f1-score   support
#
#            0       0.72      0.76      0.74       402
#            1       0.74      0.69      0.72       408
#            2       0.75      0.74      0.74       435
#            3       0.85      0.88      0.87       420
#
#     accuracy                           0.77      1665
#    macro avg       0.77      0.77      0.77      1665
# weighted avg       0.77      0.77      0.77      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Accuracy of decision tree : 0.7315315315315315
#               precision    recall  f1-score   support
#
#            0       0.70      0.74      0.72       402
#            1       0.67      0.66      0.66       408
#            2       0.73      0.72      0.72       435
#            3       0.84      0.81      0.82       420
#
#     accuracy                           0.73      1665
#    macro avg       0.73      0.73      0.73      1665
# weighted avg       0.73      0.73      0.73      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Accuracy of random forest : 0.730930930930931
#               precision    recall  f1-score   support
#
#            0       0.70      0.74      0.72       402
#            1       0.66      0.66      0.66       408
#            2       0.72      0.72      0.72       435
#            3       0.84      0.81      0.82       420
#
#     accuracy                           0.73      1665
#    macro avg       0.73      0.73      0.73      1665
# weighted avg       0.73      0.73      0.73      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
# Accuracy of neural network - Multi-Layer Perceptron (MLP) : 0.784984984984985
#               precision    recall  f1-score   support
#
#            0       0.86      0.67      0.76       402
#            1       0.82      0.65      0.73       408
#            2       0.70      0.85      0.77       435
#            3       0.80      0.95      0.87       420
#
#     accuracy                           0.78      1665
#    macro avg       0.80      0.78      0.78      1665
# weighted avg       0.79      0.78      0.78      1665
#
# Confusion matrix:
# ----------------------------------------------------------------

# %% [markdown]
# #### Results discussion
# * Accuracy is "not great, not terrible".
# * Random forest yielded the best accuracy (0.89 with location info, 0.82 without).

# %% [markdown]
# ### Classification on principal components
# #### Code

# %%
def getPcaDf(df, features, targetVar=0.95):
  # separate features from target
  x = df.loc[:, features].values # x represents our features

  # standardization, see the following articles: 
  # 1. https://towardsdatascience.com/scale-standardize-or-normalize-with-scikit-learn-6ccc7d176a02
  # 2. https://towardsdatascience.com/a-step-by-step-explanation-of-principal-component-analysis-b836fb9c97e2
  from sklearn.preprocessing import StandardScaler
  x = StandardScaler().fit_transform(x) # subtract mean and then scale to unit variance

  # run PCA
  from sklearn import decomposition
  pca = decomposition.PCA(targetVar) # maintain a targetVar portion of the variance
  pca.fit(x) 

  print("Found", pca.n_components_, "PCA components:", pca.explained_variance_)
  print("Explained variance ratios:", pca.explained_variance_ratio_, "total:", \
        sum(pca.explained_variance_ratio_))

  prinComps = pca.transform(x) # apply dimensionality reduction to x

  # create a data frame out of x
  pcaDf = pandas.DataFrame(data = prinComps)
  pcaDf['dataRateMean'] =  df['dataRateMean']

  return pcaDf

def runClassifiersOuterPc(df, featuresOfInterest):
  pcaDf = getPcaDf(df=df, features=featuresOfInterest)
  runClassifiersInner(df=pcaDf, targetName="dataRateMean", scaler=None, nquantiles=4)

# %% [markdown]
# #### Classification with client location info

# %%
runClassifiersOuterPc(df=dataset, 
                      featuresOfInterest=['receiverX', 'receiverY', 'receiverDist', \
                                          'receiverSpeed', 'receiverAlt', \
                                          'channelFreq', 'channelBw', 'rssiMean'])
# Out:
# Found 6 PCA components: [2.83777646 2.00023362 1.50756115 0.84120669 0.38076478 0.27464296]
# Explained variance ratios: [0.35465812 0.24998414 0.18841118 0.10513188 0.04758702 0.03432418] total: 0.9800965172976589
# Discretizing dataRateMean into 4 quantiles, yielding bins:
#  [Interval(-0.001, 8.625, closed='right')
#  Interval(8.625, 62.89, closed='right')
#  Interval(62.89, 104.029, closed='right')
#  Interval(104.029, 292.69, closed='right')]
# ----------------------------------------------------------------
#
# Accuracy of logistic regression : 0.8126126126126126
#               precision    recall  f1-score   support
#
#            0       0.78      0.86      0.82       402
#            1       0.74      0.67      0.70       408
#            2       0.88      0.82      0.85       435
#            3       0.85      0.90      0.87       420
#
#     accuracy                           0.81      1665
#    macro avg       0.81      0.81      0.81      1665
# weighted avg       0.81      0.81      0.81      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Accuracy of support vector machine : 0.8636636636636636
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85       402
#            1       0.87      0.79      0.83       408
#            2       0.90      0.84      0.87       435
#            3       0.86      0.95      0.90       420
#
#     accuracy                           0.86      1665
#    macro avg       0.86      0.86      0.86      1665
# weighted avg       0.87      0.86      0.86      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Accuracy of k-Nearest Neighbors : 0.8744744744744745
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88       402
#            1       0.84      0.80      0.82       408
#            2       0.85      0.88      0.86       435
#            3       0.94      0.93      0.93       420
#
#     accuracy                           0.87      1665
#    macro avg       0.87      0.87      0.87      1665
# weighted avg       0.87      0.87      0.87      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Accuracy of decision tree : 0.8294294294294294
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83       402
#            1       0.80      0.75      0.77       408
#            2       0.80      0.86      0.83       435
#            3       0.90      0.88      0.89       420
#
#     accuracy                           0.83      1665
#    macro avg       0.83      0.83      0.83      1665
# weighted avg       0.83      0.83      0.83      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Accuracy of random forest : 0.8708708708708709
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.87       402
#            1       0.83      0.81      0.82       408
#            2       0.87      0.86      0.87       435
#            3       0.92      0.94      0.93       420
#
#     accuracy                           0.87      1665
#    macro avg       0.87      0.87      0.87      1665
# weighted avg       0.87      0.87      0.87      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
# Accuracy of neural network - Multi-Layer Perceptron (MLP) : 0.8702702702702703
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88       402
#            1       0.82      0.81      0.82       408
#            2       0.84      0.86      0.85       435
#            3       0.93      0.94      0.94       420
#
#     accuracy                           0.87      1665
#    macro avg       0.87      0.87      0.87      1665
# weighted avg       0.87      0.87      0.87      1665
#
# Confusion matrix:
# ----------------------------------------------------------------

# %% [markdown]
# #### Classification without client location info

# %%
runClassifiersOuterPc(df=dataset, featuresOfInterest=['channelFreq', 'channelBw', 'rssiMean'])
# Out:
# Found 2 PCA components: [2.00073484 0.99980599]
# Explained variance ratios: [0.66679141 0.33320859] total: 1.0
# Discretizing dataRateMean into 4 quantiles, yielding bins:
#  [Interval(-0.001, 8.625, closed='right')
#  Interval(8.625, 62.89, closed='right')
#  Interval(62.89, 104.029, closed='right')
#  Interval(104.029, 292.69, closed='right')]
# ----------------------------------------------------------------
#
# Accuracy of logistic regression : 0.781981981981982
#               precision    recall  f1-score   support
#
#            0       0.74      0.81      0.77       402
#            1       0.78      0.60      0.68       408
#            2       0.87      0.73      0.80       435
#            3       0.76      0.99      0.86       420
#
#     accuracy                           0.78      1665
#    macro avg       0.79      0.78      0.78      1665
# weighted avg       0.79      0.78      0.78      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Accuracy of support vector machine : 0.787987987987988
#               precision    recall  f1-score   support
#
#            0       0.70      0.86      0.77       402
#            1       0.89      0.58      0.70       408
#            2       0.84      0.73      0.78       435
#            3       0.78      0.98      0.86       420
#
#     accuracy                           0.79      1665
#    macro avg       0.80      0.79      0.78      1665
# weighted avg       0.80      0.79      0.78      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Accuracy of k-Nearest Neighbors : 0.7675675675675676
#               precision    recall  f1-score   support
#
#            0       0.72      0.76      0.74       402
#            1       0.75      0.70      0.72       408
#            2       0.75      0.74      0.74       435
#            3       0.85      0.88      0.87       420
#
#     accuracy                           0.77      1665
#    macro avg       0.77      0.77      0.77      1665
# weighted avg       0.77      0.77      0.77      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Accuracy of decision tree : 0.7321321321321321
#               precision    recall  f1-score   support
#
#            0       0.70      0.74      0.72       402
#            1       0.67      0.66      0.66       408
#            2       0.73      0.72      0.72       435
#            3       0.84      0.81      0.82       420
#
#     accuracy                           0.73      1665
#    macro avg       0.73      0.73      0.73      1665
# weighted avg       0.73      0.73      0.73      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Accuracy of random forest : 0.730930930930931
#               precision    recall  f1-score   support
#
#            0       0.70      0.74      0.72       402
#            1       0.66      0.66      0.66       408
#            2       0.72      0.72      0.72       435
#            3       0.84      0.81      0.82       420
#
#     accuracy                           0.73      1665
#    macro avg       0.73      0.73      0.73      1665
# weighted avg       0.73      0.73      0.73      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
# Accuracy of neural network - Multi-Layer Perceptron (MLP) : 0.7825825825825826
#               precision    recall  f1-score   support
#
#            0       0.80      0.71      0.75       402
#            1       0.76      0.71      0.74       408
#            2       0.72      0.81      0.76       435
#            3       0.85      0.90      0.88       420
#
#     accuracy                           0.78      1665
#    macro avg       0.78      0.78      0.78      1665
# weighted avg       0.78      0.78      0.78      1665
#
# Confusion matrix:
# ----------------------------------------------------------------

# %% [markdown]
# #### Results discussion
# * For the w/ location info case, kNN was best with an accuracy of 0.87. For the wo/ location info case, SVM was best with 0.79 accuracy.
#
# * PCA didn't actually improve accuracy. Focusing on the w/ location info case, we went from a best of 0.89 with random forest to 0.87 with kNN. Not sure why?

# %% [markdown]
# ## Data rate prediction as a regression problem
# Predict data rate as a continuous variable.
# ### Code

# %%
from sklearn.linear_model import LinearRegression
from sklearn import svm
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy
import seaborn as sns
import matplotlib.pyplot as plt

def rmse(yTrue, yPred):
  """
    Compute root mean square error.
  """
  return numpy.sqrt(numpy.mean(numpy.square(yTrue - yPred)))

def testRegUnderClass(regName, yTrain, yTest, yPred, nquantiles=4):
  """
    See how well regression does under the classification task.
  """

  ySeries = pandas.concat([yTrain, yTest])
  _, bins = pandas.qcut(ySeries, q=nquantiles, labels=False, retbins=True) # actually discretize stuff
  bins[0] -= 1 # ensure zeros fit in 1st interval
  
  yTestCat = pandas.cut(yTest, bins=bins, labels=False)
  yPredCat = pandas.cut(yPred, bins=bins, labels=False)

  evalClfPerf(regName, yTestCat, yPredCat)

def runRegression(reg, regName, xTrain, yTrain, xTest, yTest, printSep=True):
  """
    Run single regression, passed in as argument reg.
  """

  print(regName)
  reg.fit(xTrain, yTrain)
  yPred = reg.predict(xTest) # predict on the unseen data
  yPred = yPred.clip(min=0) # because we know data rate can't be negative, make negative values zero
  print("Root-Mean-Square Error: %.2f" % rmse(yTest, yPred))
  print('Variance score: %.2f' % r2_score(yTest, yPred)) # 1 is perfect prediction
  
  testRegUnderClass(regName, yTrain, yTest, yPred)

  if printSep: printSeparator()
    
  return yPred

def runRegressionsInner(df, targetName, scaler=None):
  """
    Run multiple regressions for the data frame passed in as argument df.
  """

  #  split dataset into training and test
  x = df.drop(targetName, axis=1) # x contains all the features
  y = df[targetName] # y contains only the label

  # scaling, see: https://towardsdatascience.com/scale-standardize-or-normalize-with-scikit-learn-6ccc7d176a02
  if scaler:
    x = scaler.fit_transform(x)

  # xTrain contains features for training, xTest contains features for testing
  # test_size = 0.3 means 30% data for testing
  # random_state = 1, is the seed value used by the random number generator
  xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size = 0.3, random_state = 1)    
    
  # some info about the data
  print("Train y data information - min:", numpy.min(yTrain), ", max:", numpy.max(yTrain), ', mean:', \
        numpy.mean(yTrain), ", standard deviation:", numpy.std(yTrain))
  print("Test y data information - min:", numpy.min(yTest), ", max:", numpy.max(yTest), ', mean:', \
        numpy.mean(yTest), ", standard deviation:", numpy.std(yTest))
  printSeparator()
    
  # train and test models

  # linear regression
  regLinr = LinearRegression()
  yPredLinr = runRegression(regLinr, "Linear regression", xTrain, yTrain, xTest, yTest, printSep=False)
#  print('Linear regression coefs: \n', regLinr.coef_)  
  printSeparator()

  # svr
  regSvr = svm.SVR(gamma='scale')
  yPredSvr = runRegression(regSvr, "Support Vector Regression (SVR)", xTrain, yTrain, xTest, yTest)

  # neural network (Multi Layer Perceptron w/ backpropagation)
  regMlp = MLPRegressor(solver='lbfgs', random_state=1, max_iter=1000)
  yPredMlp = runRegression(regMlp, "Neural network - Multi-Layer Perceptron (MLP)", xTrain, yTrain, xTest, yTest)
    
  y = numpy.array([yTrain, yTest, yPredLinr, yPredSvr, yPredMlp]) 

  # plot violins for the different y distributions
  vioInPairs = (('Train', yTrain.values), ('Test', yTest.values), ('Linear regression', yPredLinr), \
                ('Support vector regression', yPredSvr), ('Multi-layer perceptron', yPredMlp))
  vioDf = pandas.DataFrame(columns=['Dataset','Mean data rate (Mbit/s)'])
  crow = 0
  for x, yarray in vioInPairs:
    for y in yarray:
      vioDf.loc[crow] = [x, y]
      crow += 1
        
  plt.figure(figsize=(14,8)) # new figure
  sns.set(style="whitegrid")
  sns.violinplot(x='Dataset', y='Mean data rate (Mbit/s)', data=vioDf)
  plt.show()

# %% [markdown]
# ### Classification on original features
# #### Code

# %%
def runRegressionsOuterOg(df, featuresToDrop): 
  regDf = df.copy() # work on copy to preserve original

  # we don't care for some columns no more
  regDf.drop(featuresToDrop, axis=1, inplace=True)
  
  #  split dataset into training and test
  x = regDf.drop("dataRateMean", axis=1) # x contains all the features
  y = regDf["dataRateMean"] # y contains only the label

  from sklearn.preprocessing import MinMaxScaler
  mms = MinMaxScaler() # subtract minimum and divide by range
  runRegressionsInner(df=regDf, targetName="dataRateMean", scaler=mms)

# %% [markdown]
# #### Classification with client location info

# %%
runRegressionsOuterOg(df=dataset, \
                      featuresToDrop=['senderId', 'receiverId', 'receiverDist', 'channelUtil', \
                                      'nBytesReceived'])
# Out:
# Train y data information - min: 0.0 , max: 281.306773 , mean: 65.80067886144734 , standard deviation: 56.16036507546545
# Test y data information - min: 0.0 , max: 292.6900100000001 , mean: 67.34738453333334 , standard deviation: 56.72589475772961
# ----------------------------------------------------------------
#
# Linear regression
# Root-Mean-Square Error: 36.96
# Variance score: 0.58
# Accuracy of Linear regression : 0.6906906906906907
#               precision    recall  f1-score   support
#
#            0       0.91      0.41      0.57       402
#            1       0.68      0.69      0.69       408
#            2       0.53      0.93      0.67       435
#            3       0.99      0.71      0.83       420
#
#     accuracy                           0.69      1665
#    macro avg       0.78      0.69      0.69      1665
# weighted avg       0.77      0.69      0.69      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Support Vector Regression (SVR)
# Root-Mean-Square Error: 31.29
# Variance score: 0.70
# Accuracy of Support Vector Regression (SVR) : 0.7267267267267268
#               precision    recall  f1-score   support
#
#            0       0.99      0.54      0.70       402
#            1       0.58      0.89      0.70       408
#            2       0.65      0.78      0.71       435
#            3       0.99      0.69      0.81       420
#
#     accuracy                           0.73      1665
#    macro avg       0.80      0.73      0.73      1665
# weighted avg       0.80      0.73      0.73      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Neural network - Multi-Layer Perceptron (MLP)
# Root-Mean-Square Error: 19.08
# Variance score: 0.89
# Accuracy of Neural network - Multi-Layer Perceptron (MLP) : 0.806006006006006
#               precision    recall  f1-score   support
#
#            0       0.90      0.64      0.75       402
#            1       0.66      0.85      0.74       408
#            2       0.81      0.83      0.82       435
#            3       0.93      0.90      0.91       420
#
#     accuracy                           0.81      1665
#    macro avg       0.82      0.80      0.81      1665
# weighted avg       0.82      0.81      0.81      1665
#
# Confusion matrix:
# ----------------------------------------------------------------

# %% [markdown]
# #### Classification without client location info

# %%
runRegressionsOuterOg(df=dataset, \
                      featuresToDrop=['senderId', 'receiverId', 'receiverX', 'receiverY', \
                                      'receiverDist', 'receiverAlt', 'receiverSpeed', \
                                      'channelUtil', 'nBytesReceived'])
# Out:
# Train y data information - min: 0.0 , max: 281.306773 , mean: 65.80067886144734 , standard deviation: 56.16036507546545
# Test y data information - min: 0.0 , max: 292.6900100000001 , mean: 67.34738453333334 , standard deviation: 56.72589475772961
# ----------------------------------------------------------------
#
# Linear regression
# Root-Mean-Square Error: 37.57
# Variance score: 0.56
# Accuracy of Linear regression : 0.6792792792792792
#               precision    recall  f1-score   support
#
#            0       0.94      0.41      0.57       402
#            1       0.65      0.69      0.67       408
#            2       0.52      0.91      0.66       435
#            3       0.97      0.69      0.81       420
#
#     accuracy                           0.68      1665
#    macro avg       0.77      0.67      0.68      1665
# weighted avg       0.77      0.68      0.68      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Support Vector Regression (SVR)
# Root-Mean-Square Error: 32.36
# Variance score: 0.67
# Accuracy of Support Vector Regression (SVR) : 0.7243243243243244
#               precision    recall  f1-score   support
#
#            0       0.99      0.54      0.70       402
#            1       0.61      0.86      0.72       408
#            2       0.61      0.80      0.69       435
#            3       0.95      0.69      0.80       420
#
#     accuracy                           0.72      1665
#    macro avg       0.79      0.72      0.73      1665
# weighted avg       0.79      0.72      0.73      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Neural network - Multi-Layer Perceptron (MLP)
# Root-Mean-Square Error: 26.50
# Variance score: 0.78
# Accuracy of Neural network - Multi-Layer Perceptron (MLP) : 0.7561561561561562
#               precision    recall  f1-score   support
#
#            0       0.97      0.58      0.73       402
#            1       0.60      0.87      0.71       408
#            2       0.74      0.73      0.74       435
#            3       0.88      0.84      0.86       420
#
#     accuracy                           0.76      1665
#    macro avg       0.80      0.76      0.76      1665
# weighted avg       0.80      0.76      0.76      1665
#
# Confusion matrix:
# ----------------------------------------------------------------

# %% [markdown]
# #### Results discussion
# * MLP neural network significantly outperformed the other methods in terms of RMSE.
# * MLP meural network was significantly slower than other methods (a few seconds vs instantenous).
# * The lack of client location info noticeably impacts performance. RMSE shot up from 19.08 vs 26.50 for MLP.

# %% [markdown]
# ### Classification on principal components
# I.e. perform PCA first.
# #### Code

# %%
def runRegressionsOuterPc(df, featuresOfInterest):
  pcaDf = getPcaDf(df=df, features=featuresOfInterest, targetVar=0.99) # 99% variance works better here
  runRegressionsInner(df=pcaDf, targetName="dataRateMean", scaler=None)

# %% [markdown]
# #### Classification with client location info

# %%
runRegressionsOuterPc(df=dataset, 
                      featuresOfInterest=['receiverX', 'receiverY', 'receiverSpeed', \
                                          'receiverAlt', 'channelFreq', 'channelBw', 'rssiMean'])
# Out:
# Found 6 PCA components: [2.52094456 1.98671916 1.24594455 0.75087036 0.29171943 0.20506388]
# Explained variance ratios: [0.36007002 0.28376587 0.17796    0.10724786 0.04166669 0.02928956] total: 0.9999999999999999
# Train y data information - min: 0.0 , max: 281.306773 , mean: 65.80067886144734 , standard deviation: 56.16036507546545
# Test y data information - min: 0.0 , max: 292.6900100000001 , mean: 67.34738453333334 , standard deviation: 56.72589475772961
# ----------------------------------------------------------------
#
# Linear regression
# Root-Mean-Square Error: 37.04
# Variance score: 0.57
# Accuracy of Linear regression : 0.6894894894894895
#               precision    recall  f1-score   support
#
#            0       0.91      0.41      0.57       402
#            1       0.69      0.69      0.69       408
#            2       0.52      0.93      0.67       435
#            3       1.00      0.71      0.83       420
#
#     accuracy                           0.69      1665
#    macro avg       0.78      0.68      0.69      1665
# weighted avg       0.78      0.69      0.69      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Support Vector Regression (SVR)
# Root-Mean-Square Error: 28.83
# Variance score: 0.74
# Accuracy of Support Vector Regression (SVR) : 0.7483483483483484
#               precision    recall  f1-score   support
#
#            0       0.99      0.57      0.72       402
#            1       0.64      0.84      0.73       408
#            2       0.63      0.86      0.72       435
#            3       0.99      0.72      0.83       420
#
#     accuracy                           0.75      1665
#    macro avg       0.81      0.75      0.75      1665
# weighted avg       0.81      0.75      0.75      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Neural network - Multi-Layer Perceptron (MLP)
# Root-Mean-Square Error: 17.67
# Variance score: 0.90
# Accuracy of Neural network - Multi-Layer Perceptron (MLP) : 0.8
#               precision    recall  f1-score   support
#
#            0       0.90      0.60      0.72       402
#            1       0.64      0.84      0.73       408
#            2       0.81      0.85      0.83       435
#            3       0.93      0.90      0.92       420
#
#     accuracy                           0.80      1665
#    macro avg       0.82      0.80      0.80      1665
# weighted avg       0.82      0.80      0.80      1665
#
# Confusion matrix:
# ----------------------------------------------------------------

# %% [markdown]
# #### Classification without client location info

# %%
runRegressionsOuterPc(df=dataset, 
                      featuresOfInterest=['channelFreq', 'channelBw', 'rssiMean'])
# Out:
# Found 2 PCA components: [2.00073484 0.99980599]
# Explained variance ratios: [0.66679141 0.33320859] total: 1.0
# Train y data information - min: 0.0 , max: 281.306773 , mean: 65.80067886144734 , standard deviation: 56.16036507546545
# Test y data information - min: 0.0 , max: 292.6900100000001 , mean: 67.34738453333334 , standard deviation: 56.72589475772961
# ----------------------------------------------------------------
#
# Linear regression
# Root-Mean-Square Error: 40.94
# Variance score: 0.48
# Accuracy of Linear regression : 0.5093093093093093
#               precision    recall  f1-score   support
#
#            0       0.98      0.44      0.61       402
#            1       0.75      0.56      0.64       408
#            2       0.37      0.97      0.54       435
#            3       0.56      0.05      0.08       420
#
#     accuracy                           0.51      1665
#    macro avg       0.67      0.50      0.47      1665
# weighted avg       0.66      0.51      0.47      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Support Vector Regression (SVR)
# Root-Mean-Square Error: 33.27
# Variance score: 0.66
# Accuracy of Support Vector Regression (SVR) : 0.7891891891891892
#               precision    recall  f1-score   support
#
#            0       0.96      0.59      0.73       402
#            1       0.75      0.75      0.75       408
#            2       0.76      0.82      0.79       435
#            3       0.76      0.99      0.86       420
#
#     accuracy                           0.79      1665
#    macro avg       0.81      0.79      0.78      1665
# weighted avg       0.81      0.79      0.78      1665
#
# Confusion matrix:
# ----------------------------------------------------------------
#
# Neural network - Multi-Layer Perceptron (MLP)
# Root-Mean-Square Error: 28.10
# Variance score: 0.75
# Accuracy of Neural network - Multi-Layer Perceptron (MLP) : 0.7537537537537538
#               precision    recall  f1-score   support
#
#            0       0.99      0.58      0.73       402
#            1       0.60      0.83      0.69       408
#            2       0.72      0.76      0.74       435
#            3       0.88      0.84      0.86       420
#
#     accuracy                           0.75      1665
#    macro avg       0.80      0.75      0.76      1665
# weighted avg       0.79      0.75      0.76      1665
#
# Confusion matrix:
# ----------------------------------------------------------------

# %% [markdown]
# ### Results discussion
# * MLP neural network performed the best across the board.
# * MLP was the slowest method.
# * Doing PCA improved MLP performance for the w/ location info case (RMSE from 19.08 to 17.67), but reduced it in the wo/ location info case (RMSE from 26.50 to 28.1).
# * Lacking location info negatively impacts performance. In the non-PCA, MLP configuration, RMSE jumped to 26.5 from 19.08.

# %% [markdown]
# ## Conclusions and future work
# * For classification, kNN and random forest are the top performers.
# * For regression, the MLP neural network performed the best.
# * Having client location negatively affects predictability, in a significant manner.
# * Neural network may be too slow to run on an AP?
# * In the future we'll want to have experiments that give us data about the impact of channel utilization on throughput. Throughput should be a function of data rate and channel utilization.
